# %% [markdown]
# ***
# **Introduction to Machine Learning** <br>
# __[https://slds-lmu.github.io/i2ml/](https://slds-lmu.github.io/i2ml/)__
# ***

# %% [markdown]
# # Exercise sheet 3: Supervised Classification

# %% [markdown]
# ## Exercise 1: Logistic Regression Basics

# %% [markdown]
# > a) What is the relationship between softmax
# $$ \pi_k(\mathbf{x}| \mathbf{\theta}) = \frac{\exp(\mathbf{\theta}_k^T \mathbf{x})}{\sum_{j=1}^g \exp(\mathbf{\theta}_j^T \mathbf{x})},\; k \in \{1,...,g\}$$
# > and the logistic function
# $$\pi(\mathbf{x}|\mathbf{\theta}) = \frac{1}{1 + \exp(-\mathbf{\theta}^T \mathbf{x})}$$
# > for $g = 2$ (binary classification)?
#
# > **\# Entering your answer here:**

# %% [markdown]
# > b) The likelihood function for a multinomially distributed target variable with g target classes is given by[<sup>1</sup>](#fn1)
# $$\mathcal{L}_i(\mathbf{\theta}) = \mathbb{P}(y^{(i)} | \mathbf{x}^{(i)}, \mathbf{\theta}_1, \mathbf{\theta}_2, \dots, \mathbf{\theta}_g) = \prod_{j = 1}^g \pi_j \left(\mathbf{x}^{(i)} | \mathbf{\theta} \right)^{\mathbb{I}{(y^{(i)} = j)}}$$
# where the posterior class probabilities $\pi_1 \left(\mathbf{x}^{(i)} | \mathbf{\theta} \right), \pi_2 \left(\mathbf{x}^{(i)} | \mathbf{\theta} \right), \dots, \pi_g \left(\mathbf{x}^{(i)} | \mathbf{\theta} \right)$
#   are modeled with softmax regression.
#   Derive the likelihood function for $n$ independent observations.
#
#
# > **\# Entering your answer here:**

# %% [markdown]
# > c) We have already addressed the connection that holds between maximum likelihood estimation and empirical risk minimization. Transform the joint likelihood function into an empirical risk function. State the associated risk function.

# %% [markdown]
# > Hints:
# > - By following the maximum likelihood principle, we should look for parameters $\mathbf{\theta}_1$, $\mathbf{\theta}_1$, . . . , $\mathbf{\theta}_1$ that maximize the likelihood function.
# > - The expressions $\prod \mathcal{L}_i$ and $\log \prod \mathcal{L}_i$, if defined, are maximized by the same parameters.
# > - Minimizing a scalar function multiplied with -1 is equivalent to maximizing the original function.
#
# > **\# Entering your answer here:**

# %% [markdown]
# > d) Write down the discriminant functions of multiclass logistic regression resulting from this minimization objective. How do we arrive at the final prediction?
#
# > **\# Entering your answer here:**

# %% [markdown]
# > e) State the parameter space $\Theta$ and corresponding hypothesis space $\mathcal{H}$ for the multiclass case.
#
# > **\# Entering your answer here:**

# %% [markdown]
# ## Exercise 2: Decision Boundaries & Thresholds in Logistic Regression

# %% [markdown]
# In logistic regression (binary case), we estimate the probability
# $\mathbb{P}(y = 1 | \mathbf{x}, \mathbf{\theta}) = \pi(\mathbf{x}|\mathbf{\theta})$.
# In order to decide about the class of an observation, we set $\hat{y} = 1$ iff
# $\hat{\pi}(\mathbf{x} | \hat{\mathbf{\theta}}) \geq \alpha$ for some $\alpha \in (0, 1)$.

# %% [markdown]
# > a) Show that the decision boundary of the logistic classifier is a (linear!) hyperplane. <br>
# Hint: derive the value of $\hat{\mathbf{\theta}}^T \mathbf{x}$ (depending on α) starting from which you predict $\hat{y} = 1$ rather than $\hat{y} = 0$.
#
# > **\# Entering your answer here:**

# %% [markdown]
# > b) Below you see the logistic function for a binary classification problem with two input features for different values
# $\hat{\mathbf{\theta}} = (\hat{\mathbf{\theta}}_1, \hat{\mathbf{\theta}}_2)$ (plots 1-3) as well as $\alpha$ (plot 4). What can you deduce for the values of $\hat{\mathbf{\theta}}_1$, $\hat{\mathbf{\theta}}_2$ and $\alpha$? What are the implications for classification in the different scenarios?

# %% [markdown]
# ![softmax_1.png](attachment:softmax_1.png) Plot (1)

# %% [markdown]
# ![softmax_2.png](attachment:softmax_2.png) Plot (2)

# %% [markdown]
# ![softmax_3.png](attachment:softmax_3.png) Plot (3)

# %% [markdown]
# ![softmax_4.png](attachment:softmax_4.png) Plot (4)
#
# > **\# Entering your answer here:**

# %% [markdown]
# > c) Derive the equation for the decision boundary hyperplane if we choose $\alpha = 0.5$.
#
# > **\# Entering your answer here:**

# %% [markdown]
# > d) Explain when it might be sensible to set $\alpha$ to $0.5$.
#
# > **\# Entering your answer here:**

# %% [markdown]
# ***
# <span id="fn1">[1] While this might look somewhat complicated, it is actually just a very concise way to express the multinomial likelihood:
#   for each observation,
#   all factors but the one corresponding to the true class $j^\prime$ will be 1
#   (due to the 0 exponent), so the result is simply $\pi_{j^\prime}\left(\mathbf{x}^{(i)} | \mathbf{\theta} \right)$.</span>
